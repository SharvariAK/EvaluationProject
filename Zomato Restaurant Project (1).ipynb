# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("zomato.csv")
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df2=pd.read_csv("Country-Code.csv")
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
ds=pd.merge(df1,df2)
ds
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [raw]
# Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range

# %%
ds.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ds.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
ds.shape
# Out:
# (9551, 22)

# %% [markdown]
# # Checking DataTypes

# %%
ds.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# # Checking Null Values

# %%
ds.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# There are no null values present in the dataset,only in 1 column i.e Cuisine

# %% [markdown]
# # Removing Null Values

# %%
ds['Cuisines'].value_counts()
# Out:
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
ds['Cuisines'].fillna(ds['Cuisines'].mode()[0],inplace=True)

# %%
ds.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# # Target Variable

# %%
ds['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# There is data imbalance we can use SMOTE technique to balance the data

# %% [markdown]
# # EDA PROCESS

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
ds.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# # Visualization of Data

# %%
sns.countplot(ds['Country'])
print(ds['Country'].value_counts())
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
sns.countplot(ds['Has Online delivery'])
print(ds['Has Online delivery'].value_counts())
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
sns.countplot(ds['Has Table booking'])
print(ds['Has Table booking'].value_counts())
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %%
sns.countplot(ds['Currency'])
print(ds['Currency'].value_counts())
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(��)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64

# %%
sns.distplot(ds['Price range'],kde=True)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Density'>

# %%
sns.distplot(ds['Average Cost for two'],kde=True)
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Density'>

# %%
sns.distplot(ds['Votes'],kde=True)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
sns.distplot(ds['Aggregate rating'],kde=True)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Density'>

# %%
ds.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Restaurant ID          -0.001693
# Country Code            0.043225
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Name: Average Cost for two, dtype: float64

# %%
ds.corr()['Price range'].sort_values()
# Out:
# Latitude               -0.166688
# Restaurant ID          -0.134540
# Longitude              -0.078939
# Average Cost for two    0.075083
# Country Code            0.243327
# Votes                   0.309444
# Aggregate rating        0.437944
# Price range             1.000000
# Name: Price range, dtype: float64

# %%
ds=ds.drop(['Restaurant ID'],axis=1)
ds
# Out:
#                Restaurant Name  Country Code              City  \
# 0             Le Petit Souffle           162       Makati City
# 1             Izakaya Kikufuji           162       Makati City
# 2       Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                         Ooma           162  Mandaluyong City
# 4                  Sambo Kojin           162  Mandaluyong City
# ...                        ...           ...               ...
# 9546               Naml۱ Gurme           208         ��stanbul
# 9547              Ceviz A��ac۱           208         ��stanbul
# 9548                     Huqqa           208         ��stanbul
# 9549               A���k Kahve           208         ��stanbul
# 9550  Walter's Coffee Roastery           208         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# ...

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
columns=['Restaurant Name', 'City', 'Address',
                'Locality', 'Locality Verbose','Currency','Cuisines', 'Has Table booking',
                'Has Online delivery','Is delivering now', 'Switch to order menu',
                'Rating color', 'Rating text','Country']
le=LabelEncoder()
for cols in columns:
    ds[cols]=le.fit_transform(ds[cols])

# %%
ds
# Out:
#       Restaurant Name  Country Code  City  Address  Locality  \
# 0                3749           162    73     8685       171
# 1                3173           162    73     6055       593
# 2                2897           162    75     4684       308
# 3                4707           162    75     8690       862
# 4                5523           162    75     8689       862
# ...               ...           ...   ...      ...       ...
# 9546             4443           208   140     5926       517
# 9547             1311           208   140     5962       552
# 9548             3069           208   140     5966       554
# 9549              513           208   140     5967       554
# 9550             7240           208   140     4258       670
#
#       Locality Verbose   Longitude   Latitude  Cuisines  Average Cost for two  \
# 0                  172  121.027535  14.565443       920                  1100
# ...

# %%
ds.dtypes
# Out:
# Restaurant Name           int32
# Country Code              int64
# City                      int32
# Address                   int32
# Locality                  int32
# Locality Verbose          int32
# Longitude               float64
# Latitude                float64
# Cuisines                  int32
# Average Cost for two      int64
# Currency                  int32
# Has Table booking         int32
# Has Online delivery       int32
# Is delivering now         int32
# Switch to order menu      int32
# Price range               int64
# Aggregate rating        float64
# Rating color              int32
# Rating text               int32
# Votes                     int64
# Country                   int32
# dtype: object

# %% [markdown]
# # Checking Outliers

# %%
ds.plot(kind='box',subplots=True,layout=(2,12))
# Out:
# Restaurant Name            AxesSubplot(0.125,0.536818;0.0545775x0.343182)
# Country Code            AxesSubplot(0.190493,0.536818;0.0545775x0.343182)
# City                    AxesSubplot(0.255986,0.536818;0.0545775x0.343182)
# Address                 AxesSubplot(0.321479,0.536818;0.0545775x0.343182)
# Locality                AxesSubplot(0.386972,0.536818;0.0545775x0.343182)
# Locality Verbose        AxesSubplot(0.452465,0.536818;0.0545775x0.343182)
# Longitude               AxesSubplot(0.517958,0.536818;0.0545775x0.343182)
# Latitude                AxesSubplot(0.583451,0.536818;0.0545775x0.343182)
# Cuisines                AxesSubplot(0.648944,0.536818;0.0545775x0.343182)
# Average Cost for two    AxesSubplot(0.714437,0.536818;0.0545775x0.343182)
# Currency                 AxesSubplot(0.77993,0.536818;0.0545775x0.343182)
# Has Table booking       AxesSubplot(0.845423,0.536818;0.0545775x0.343182)
# Has Online delivery           AxesSubplot(0.125,0.125;0.0545775x0.343182)
# ...

# %% [markdown]
# Outliers are present in some columns we can remove it using zscore.

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(ds))
threshold=3
np.where(z>3)
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550], dtype=int64),
#  array([10, 10, 10, ..., 10,  1, 10], dtype=int64))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(ds.corr(),annot=True,linewidth=0.5,linecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Training and Testing Data

# %%
x=ds.drop(columns=['Price range'],axis=1)
x
# Out:
#       Restaurant Name  Country Code  City  Address  Locality  \
# 0                3749           162    73     8685       171
# 1                3173           162    73     6055       593
# 2                2897           162    75     4684       308
# 3                4707           162    75     8690       862
# 4                5523           162    75     8689       862
# ...               ...           ...   ...      ...       ...
# 9546             4443           208   140     5926       517
# 9547             1311           208   140     5962       552
# 9548             3069           208   140     5966       554
# 9549              513           208   140     5967       554
# 9550             7240           208   140     4258       670
#
#       Locality Verbose   Longitude   Latitude  Cuisines  Average Cost for two  \
# 0                  172  121.027535  14.565443       920                  1100
# ...

# %%
y=ds['Price range']
y
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %%
import sklearn

# %%
import numpy

# %%
# !pip install scikit-learn

# %% [markdown]
# # !pip install imblearn --user

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
trainx,trainy=smt.fit_resample(x,y)

# %%
trainx.value_counts()
# Out:
# Restaurant Name  Country Code  City  Address  Locality  Locality Verbose  Longitude   Latitude   Cuisines  Average Cost for two  Currency  Has Table booking  Has Online delivery  Is delivering now  Switch to order menu  Aggregate rating  Rating color  Rating text  Votes  Country
# 0                1             89    3969     959       1009               0.000000   0.000000   549       400                   4         0                  0                    0                  0                     0.000000          4             3            0      3          1
# 4961             1             88    8690     1083      1136               77.314183  28.587303  1102      1000                  4         0                  0                    0                  0                     3.326244          4             2            199    3          1
# ...

# %%
trainy.value_counts()
# Out:
# 3    4444
# 4    4444
# 2    4444
# 1    4444
# Name: Price range, dtype: int64

# %%
trainy
# Out:
# 0        3
# 1        3
# 2        4
# 3        4
# 4        4
#         ..
# 17771    4
# 17772    4
# 17773    4
# 17774    4
# 17775    4
# Name: Price range, Length: 17776, dtype: int64

# %%
sns.countplot(trainy)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %% [markdown]
# The data is properly scaled now we can proceed now.

# %% [markdown]
# # Scalling the data using Min-Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
st=MinMaxScaler()
x=st.fit_transform(x)
x
# Out:
# array([[0.50355944, 0.74883721, 0.52142857, ..., 0.2       , 0.02871776,
#         0.42857143],
#        [0.42619208, 0.74883721, 0.52142857, ..., 0.2       , 0.05405158,
#         0.42857143],
#        [0.38912021, 0.74883721, 0.53571429, ..., 1.        , 0.02469362,
#         0.42857143],
#        ...,
#        [0.41222297, 0.9627907 , 1.        , ..., 0.4       , 0.06045363,
#         0.78571429],
#        [0.06890531, 0.9627907 , 1.        , ..., 1.        , 0.08240351,
#         0.78571429],
#        [0.97246474, 0.9627907 , 1.        , ..., 1.        , 0.05405158,
#         0.78571429]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=0.30,random_state=45)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
model=rfc.fit(x_train,y_train)
prediction=model.predict(x_test)
print('Accuracy on training data:',format(rfc.score(x_train,y_train)))
print('Accuracy on testing data:',format(rfc.score(x_test,y_test)))
# Out:
# Accuracy on training data: 1.0
# Accuracy on testing data: 0.9763735233452091

# %%
predrfc=rfc.predict(x_test)
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# [[1347    9    0    0]
#  [  11 1274   27    5]
#  [   0   17 1267   27]
#  [   0    0   30 1319]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1356
#            2       0.98      0.97      0.97      1317
#            3       0.96      0.97      0.96      1311
#            4       0.98      0.98      0.98      1349
#
#     accuracy                           0.98      5333
#    macro avg       0.98      0.98      0.98      5333
# weighted avg       0.98      0.98      0.98      5333

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
model=dtc.fit(x_train,y_train)
prediction=model.predict(x_test)
print('Accuracy on training data:',format(dtc.score(x_train,y_train)))
print('Accuracy on testing data:',format(dtc.score(x_test,y_test)))
# Out:
# Accuracy on training data: 1.0
# Accuracy on testing data: 0.9632477029814364

# %%
preddtc=dtc.predict(x_test)
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# [[1350    6    0    0]
#  [   7 1275   30    5]
#  [   0   28 1234   49]
#  [   0    2   69 1278]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1356
#            2       0.97      0.97      0.97      1317
#            3       0.93      0.94      0.93      1311
#            4       0.96      0.95      0.95      1349
#
#     accuracy                           0.96      5333
#    macro avg       0.96      0.96      0.96      5333
# weighted avg       0.96      0.96      0.96      5333

# %%
from sklearn.svm import SVC
svc=SVC()
model=svc.fit(x_train,y_train)
prediction=model.predict(x_test)
print('Accuracy on training data:',format(svc.score(x_train,y_train)))
print('Accuracy on testing data:',format(svc.score(x_test,y_test)))
# Out:
# Accuracy on training data: 0.7250663023386643
# Accuracy on testing data: 0.7172323270204388

# %%
predsvc=svc.predict(x_test)
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# [[1243  111    2    0]
#  [ 214 1069   34    0]
#  [ 210  179  811  111]
#  [ 356   74  217  702]]
#               precision    recall  f1-score   support
#
#            1       0.61      0.92      0.74      1356
#            2       0.75      0.81      0.78      1317
#            3       0.76      0.62      0.68      1311
#            4       0.86      0.52      0.65      1349
#
#     accuracy                           0.72      5333
#    macro avg       0.75      0.72      0.71      5333
# weighted avg       0.75      0.72      0.71      5333

# %%
from sklearn.neighbors import  KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
pred
# Out:
# array([4, 4, 4, ..., 3, 3, 1], dtype=int64)

# %%
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.8336771048190512
# [[1034  249   24   49]
#  [ 193 1025   71   28]
#  [  43   72 1148   48]
#  [  50   16   44 1239]]
#               precision    recall  f1-score   support
#
#            1       0.78      0.76      0.77      1356
#            2       0.75      0.78      0.77      1317
#            3       0.89      0.88      0.88      1311
#            4       0.91      0.92      0.91      1349
#
#     accuracy                           0.83      5333
#    macro avg       0.83      0.83      0.83      5333
# weighted avg       0.83      0.83      0.83      5333

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
model=rfc.fit(x_train,y_train)
prediction=model.predict(x_test)
print('Accuracy on training data:',format(rfc.score(x_train,y_train)))
print('Accuracy on testing data:',format(rfc.score(x_test,y_test)))
model=RandomForestClassifier(n_estimators=100,min_samples_split=25,max_depth=7,max_features=1)
# Out:
# Accuracy on training data: 1.0
# Accuracy on testing data: 0.9750609413088318

# %% [markdown]
# As it is a multiclass format we will plot ROC-AUC CURVE FOR MULTICLASS FORMAT

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve,auc

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(y)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

colors = cycle(["aqua", "darkorange", "cornflowerblue"])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Some extension of Receiver operating characteristic to multiclass")
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [63], in <cell line: 2>()
#       1 # First aggregate all false positive rates
# ----> 2 all_fpr = np.unique(np.concatenate([fpr[i] for i in range(y)]))
#       4 # Then interpolate all ROC curves at this points
#       5 mean_tpr = np.zeros_like(all_fpr)
#
# TypeError: 'Series' object cannot be interpreted as an integer

# %% [markdown]
# # To predict Average Cost for two

# %%
x=ds.drop(columns=['Average Cost for two'],axis=1)
x
# Out:
#       Restaurant Name  Country Code  City  Address  Locality  \
# 0                3749           162    73     8685       171
# 1                3173           162    73     6055       593
# 2                2897           162    75     4684       308
# 3                4707           162    75     8690       862
# 4                5523           162    75     8689       862
# ...               ...           ...   ...      ...       ...
# 9546             4443           208   140     5926       517
# 9547             1311           208   140     5962       552
# 9548             3069           208   140     5966       554
# 9549              513           208   140     5967       554
# 9550             7240           208   140     4258       670
#
#       Locality Verbose   Longitude   Latitude  Cuisines  Currency  \
# 0                  172  121.027535  14.565443       920         0
# 1                  601  121.014101  14.553708      1111         0
# ...

# %%
y=ds['Average Cost for two']
y
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9551, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=0.30,random_state=45)

# %% [markdown]
# # Scalling the data using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
st=StandardScaler()
x=st.fit_transform(x)
x
# Out:
# array([[ 0.0447056 ,  2.53111053, -0.22853276, ..., -0.4654417 ,
#          0.36520164,  0.85345723],
#        [-0.22410085,  2.53111053, -0.22853276, ..., -0.4654417 ,
#          1.0091681 ,  0.85345723],
#        [-0.35290395,  2.53111053, -0.14231731, ...,  1.89507002,
#          0.26291094,  0.85345723],
#        ...,
#        [-0.27263535,  3.34171786,  2.65968456, ...,  0.12468623,
#          1.17190331,  2.73895179],
#        [-1.46546399,  3.34171786,  2.65968456, ...,  1.89507002,
#          1.72985259,  2.73895179],
#        [ 1.67387805,  3.34171786,  2.65968456, ...,  1.89507002,
#          1.0091681 ,  2.73895179]])

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
model=rfr.fit(x_train,y_train)
prediction=model.predict(x_test)
print('Accuracy on training data:',format(rfr.score(x_train,y_train)))
print('Accuracy on testing data:',format(rfr.score(x_test,y_test)))
# Out:
# Accuracy on training data: 0.9977836540318638
# Accuracy on testing data: 0.9825391470422453

# %%
print(accuracy_score(pred,y_test))
print(confusion_matrix(pred,y_test))
print(classification_report(pred,y_test))
# Out:
# 0.8336771048190512
# [[1034  193   43   50]
#  [ 249 1025   72   16]
#  [  24   71 1148   44]
#  [  49   28   48 1239]]
#               precision    recall  f1-score   support
#
#            1       0.76      0.78      0.77      1320
#            2       0.78      0.75      0.77      1362
#            3       0.88      0.89      0.88      1287
#            4       0.92      0.91      0.91      1364
#
#     accuracy                           0.83      5333
#    macro avg       0.83      0.83      0.83      5333
# weighted avg       0.83      0.83      0.83      5333

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
knr.score(x_train,y_train)
predknr=knr.predict(x_test)
print(predknr)
knr.score(x_test,y_test)
# Out:
# [4. 3. 4. ... 3. 3. 1.]
# 0.7848089046167895

# %%
from sklearn.tree import DecisionTreeRegressor 
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(preddtc)
dtc.score(x_test,y_test)
# Out:
# [4. 3. 4. ... 3. 3. 1.]
# 0.9704888579669909

# %%
print(accuracy_score(pred,y_test))
print(confusion_matrix(pred,y_test))
print(classification_report(pred,y_test))
# Out:
# 0.8336771048190512
# [[1034  193   43   50]
#  [ 249 1025   72   16]
#  [  24   71 1148   44]
#  [  49   28   48 1239]]
#               precision    recall  f1-score   support
#
#            1       0.76      0.78      0.77      1320
#            2       0.78      0.75      0.77      1362
#            3       0.88      0.89      0.88      1287
#            4       0.92      0.91      0.91      1364
#
#     accuracy                           0.83      5333
#    macro avg       0.83      0.83      0.83      5333
# weighted avg       0.83      0.83      0.83      5333

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mnb=MultinomialNB()
mnb.fit(abs(x_train),abs(y_train))
pred=mnb.predict(abs(x_test))
pred
# Out:
# array([1, 4, 3, ..., 4, 4, 1], dtype=int64)

# %%
print(accuracy_score(pred,y_test))
print(confusion_matrix(pred,y_test))
print(classification_report(pred,y_test))
# Out:
# 0.47140446277892367
# [[958 421  50 159]
#  [384 775 528 274]
#  [  2   9  86 221]
#  [ 12 112 647 695]]
#               precision    recall  f1-score   support
#
#            1       0.71      0.60      0.65      1588
#            2       0.59      0.40      0.47      1961
#            3       0.07      0.27      0.11       318
#            4       0.52      0.47      0.49      1466
#
#     accuracy                           0.47      5333
#    macro avg       0.47      0.44      0.43      5333
# weighted avg       0.57      0.47      0.51      5333

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.savefig('rfr.png')
plt.show()
